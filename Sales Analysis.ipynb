# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading the data
sales=pd.read_csv('sales.csv')
products=pd.read_csv('products.csv')
customers=pd.read_csv('customers.csv')

# %%
#Check for any missing values in each dataset.
customers.isnull().sum()
sales.isnull().sum()
products.isnull().sum()
# Out:
# ProductID          0
# ProductName        0
# ProductCategory    0
# Supplier           0
# dtype: int64

# %%
# Example: Drop rows with missing values in sales_df
sales = sales.dropna()

# Example: Fill missing values in customers_df with a default value
customers['CustomerRegion'] = customers['CustomerRegion'].fillna('Unknown')

# %%
# Setting the date as datetime format
sales['SaleDate']=pd.to_datetime(sales['SaleDate'])

# %%
sales.dtypes
# Out:
# SaleDate        datetime64[ns]
# CustomerID               int64
# ProductID                int64
# UnitPrice              float64
# QuantitySold             int64
# TotalSales             float64
# dtype: object

# %%
# Example: Convert 'QuantitySold' to integer
sales['QuantitySold'] = sales['QuantitySold'].astype(int)

# %%
sales
# Out:
#                        SaleDate  CustomerID  ProductID  UnitPrice  \
# 0    2023-10-20 19:35:55.563595        1927        667     112.57
# 1    2022-09-27 19:35:55.563595        3150        629     140.63
# 2    2024-07-27 19:35:55.563595        8786        957     126.21
# 3    2024-06-29 19:35:55.563595        8176        735      16.81
# 4    2024-04-20 19:35:55.563595        2648        158      90.37
# ...                         ...         ...        ...        ...
# 4995 2022-11-23 19:35:55.563595        4005        378      26.48
# 4996 2022-12-04 19:35:55.563595        5007        352     159.27
# 4997 2022-10-10 19:35:55.563595        1280        555      40.35
# 4998 2024-03-23 19:35:55.563595        1763        479      42.48
# 4999 2023-11-23 19:35:55.563595        4138        835      45.05
#
#       QuantitySold  TotalSales
# 0                4      450.28
# 1                3      421.89
# 2                2      252.42
# 3                3       50.43
# ...

# %%
#Check the duplicated rows

sales.duplicated().sum()
customers.duplicated().sum()
products.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Remove duplicates

sales= sales.drop_duplicates()
customers = customers.drop_duplicates()
products= products.drop_duplicates()

# %%
sales.describe()
# Out:
#                             SaleDate   CustomerID   ProductID    UnitPrice  \
# count                           5000  5000.000000  5000.00000  5000.000000
# mean   2023-08-18 02:57:43.083595520  5433.850200   561.27080   103.305614
# min       2022-08-23 19:35:55.563595  1022.000000   104.00000     6.090000
# 25%    2023-02-16 19:35:55.563595008  3202.000000   372.00000    55.220000
# 50%    2023-08-17 19:35:55.563595008  5342.000000   560.00000   102.525000
# 75%    2024-02-13 19:35:55.563595008  7752.000000   800.00000   150.475000
# max       2024-08-21 19:35:55.563595  9991.000000   988.00000   199.950000
# std                              NaN  2588.762794   254.13849    55.776622
#
#        QuantitySold   TotalSales
# count   5000.000000  5000.000000
# mean       3.003800   310.997696
# min        1.000000     6.090000
# 25%        2.000000   122.867500
# 50%        3.000000   249.110000
# 75%        4.000000   454.870000
# max        5.000000   999.400000
# ...

# %%
customers.describe()
# Out:
#         CustomerID  CustomerAge
# count  1000.000000  1000.000000
# mean   5406.750000    43.012000
# std    2620.295318    15.251704
# min    1022.000000    18.000000
# 25%    3143.750000    30.000000
# 50%    5265.500000    42.000000
# 75%    7767.250000    56.000000
# max    9991.000000    70.000000

# %%
products.describe()
# Out:
#         ProductID
# count  100.000000
# mean   556.860000
# std    253.024134
# min    104.000000
# 25%    376.500000
# 50%    558.500000
# 75%    791.250000
# max    988.000000

# %%
# Histogram with density plot
plt.figure(figsize=(10, 6))
sns.displot(sales['TotalSales'], kde=True, color='skyblue')  # seaborn for color and density plot
plt.title('Distribution of Total Sales')
plt.xlabel('Total Sales')
plt.ylabel('Density')
plt.grid(True, linestyle='--', linewidth=0.5, color='gray')  # Adjust gridlines
plt.show()

# %%
# Set the style and color palette
sns.set(style="whitegrid")
plt.figure(figsize=(12, 8))

# Create vertical boxplot
ax = sns.boxplot(y=sales['TotalSales'], color='skyblue', fliersize=5, linewidth=1.5)

# Improve the aesthetics
plt.title('Distribution of Total Sales', fontsize=16, weight='bold')
plt.xlabel('Total Sales', fontsize=14, weight='bold')
plt.ylabel('Sales Amount', fontsize=14, weight='bold')
plt.grid(True, linestyle='--', alpha=0.7)

# Show plot
plt.show()

# %% [markdown]
# # Data Analysis

# %%
# Assuming 'SaleDate' is already in datetime format creating a new Month column
sales['Month'] = sales['SaleDate'].dt.to_period('M')

# %%
sales
# Out:
#                        SaleDate  CustomerID  ProductID  UnitPrice  \
# 0    2023-10-20 19:35:55.563595        1927        667     112.57
# 1    2022-09-27 19:35:55.563595        3150        629     140.63
# 2    2024-07-27 19:35:55.563595        8786        957     126.21
# 3    2024-06-29 19:35:55.563595        8176        735      16.81
# 4    2024-04-20 19:35:55.563595        2648        158      90.37
# ...                         ...         ...        ...        ...
# 4995 2022-11-23 19:35:55.563595        4005        378      26.48
# 4996 2022-12-04 19:35:55.563595        5007        352     159.27
# 4997 2022-10-10 19:35:55.563595        1280        555      40.35
# 4998 2024-03-23 19:35:55.563595        1763        479      42.48
# 4999 2023-11-23 19:35:55.563595        4138        835      45.05
#
#       QuantitySold  TotalSales    Month
# 0                4      450.28  2023-10
# 1                3      421.89  2022-09
# 2                2      252.42  2024-07
# ...

# %%
monthly_sales=sales.groupby('Month')['TotalSales'].sum()
# Group by Month and calculate total sales
# monthly_sales = sales_df.groupby('Month')['TotalSales'].sum()

# %%
monthly_sales
# Out:
# Month
# 2022-08    21023.12
# 2022-09    62657.99
# 2022-10    66419.03
# 2022-11    59707.53
# 2022-12    77580.44
# 2023-01    75853.06
# 2023-02    58098.91
# 2023-03    70637.84
# 2023-04    61605.03
# 2023-05    58187.45
# 2023-06    67108.57
# 2023-07    74107.81
# 2023-08    56361.95
# 2023-09    70249.47
# 2023-10    67813.99
# 2023-11    64840.17
# 2023-12    68500.57
# 2024-01    60769.81
# 2024-02    59619.67
# 2024-03    59898.63
# 2024-04    66215.81
# 2024-05    54670.30
# 2024-06    70238.44
# 2024-07    50395.78
# 2024-08    52427.11
# Freq: M, Name: TotalSales, dtype: float64

# %%
# Plot the monthly sales trend
plt.figure(figsize=(12, 6))
plt.style.use('ggplot')
monthly_sales.plot(kind='line', marker='o', color='skyblue')
plt.title('Monthly Sales Trend',font='Serif', fontsize=16, fontweight='bold')
plt.xlabel('Month', fontsize=14)
plt.ylabel('Total Sales (BDT)', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
sales['Quarter']=sales['SaleDate'].dt.to_period('Q')
Quarterly_sales=sales.groupby('Quarter')['TotalSales']

# %%
Quarterly_sales=sales.groupby('Quarter')['TotalSales'].sum()

# %%
# Plot the quarterly sales trend
plt.figure(figsize=(12, 6))
plt.style.use('ggplot')
Quarterly_sales.plot(kind='bar', color='skyblue',edgecolor='black')
plt.title('Quarterly Sales Trend',font='Serif', fontsize=16, fontweight='bold')
plt.xlabel('Quarter', fontsize=14)
plt.ylabel('Total Sales (BDT)', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Identify Top-Performing Product Categories and Regions

# %%
sales_with_product=pd.merge(sales,products, on='ProductID')

# %%
sales_with_product=sales_with_product.drop(columns='Quarter')

# %%
p_category=sales_with_product.groupby('ProductCategory')['TotalSales'].sum()

# %%
p_category.sort_values(ascending=False)
# Out:
# ProductCategory
# Home Goods     406427.48
# Books          400070.67
# Electronics    320233.48
# Clothing       224716.20
# Groceries      203540.65
# Name: TotalSales, dtype: float64

# %%
sales_with_customer=pd.merge(sales,customers,on='CustomerID')
region=sales_with_customer.groupby('CustomerRegion')['TotalSales'].sum()

# %%
print(region)
# Out:
# CustomerRegion
# Chittagong    300843.18
# Dhaka         337620.17
# Khulna        312042.52
# Rajshahi      323253.34
# Sylhet        281229.27
# Name: TotalSales, dtype: float64

# %% [markdown]
# # Calculate Key Performance Indicators (KPIs)

# %% [markdown]
# #### Average Order Value (AOV):

# %%
# Calculate Average Order Value
aov = sales['TotalSales'].mean()
print(f"Average Order Value (AOV): {aov:.2f} BDT")
# Out:
# Average Order Value (AOV): 311.00 BDT

# %% [markdown]
# #### Customer Lifetime Value (CLV):

# %%
# Calculate Customer Lifetime Value (Total Sales / Number of Customers)
total_sales_per_customer=sales.groupby('CustomerID')['TotalSales'].sum()
clv=total_sales_per_customer.mean()
print(f"Customer Life Time Value : {clv:.2f} BDT")
# Out:
# Customer Life Time Value : 1567.53 BDT

# %% [markdown]
# #### Sales Growth

# %%
# Calculate sales growth rate
monthly_sales_diff = monthly_sales.diff().dropna()
sales_growth_rate = (monthly_sales_diff / monthly_sales.shift(1)).dropna() * 100

# Display the average sales growth rate
average_growth_rate = sales_growth_rate.mean()
print(f"Average Monthly Sales Growth Rate: {average_growth_rate:.2f}%")
# Out:
# Average Monthly Sales Growth Rate: 8.77%

# %%
q_dif=Quarterly_sales.diff().dropna()
quarters_growth=(q_dif/Quarterly_sales.shift(1)).dropna()*100

avg_g=quarters_growth.mean()
print(f"Average quarterly Growth rate of quarter:{avg_g:.2f} %")
# Out:
# Average quarterly Growth rate of quarter:11.53 %

# %% [markdown]
# #### Segment Customers Based on Purchase Behavior

# %%
# Calculate Recency (days since last purchase)
recent_purchase = sales.groupby('CustomerID')['SaleDate'].max()   #which customer bought the products most
recency = (sales['SaleDate'].max() - recent_purchase).dt.days

# Calculate Frequency (number of purchases)
frequency = sales.groupby('CustomerID')['SaleDate'].count()

# Calculate Monetary Value (total spending)
monetary = sales.groupby('CustomerID')['TotalSales'].sum()

# Combine RFM values into a DataFrame
rfm_df = pd.DataFrame({
    'Recency': recency,
    'Frequency': frequency,
    'Monetary': monetary
})

# Display the first few rows of the RFM DataFrame
rfm_df.head(10)
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 1022             32         11   3422.58
# 1038             56          6   2417.18
# 1039            397          2    220.57
# 1044            147          4   1202.32
# 1047            532          2    163.13
# 1057            361          1    332.90
# 1067            237          5   1218.34
# 1074            202          3    769.19
# 1079            216          2    237.51
# 1084              7          6   2078.96

# %% [markdown]
# ### Find the Top 10 Products by Sales in a Specific Region

# %%
merged_data=sales.merge(products,on='ProductID').merge(customers,on='CustomerID')
merged_data
# Out:
#                        SaleDate  CustomerID  ProductID  UnitPrice  \
# 0    2023-10-20 19:35:55.563595        1927        667     112.57
# 1    2022-09-27 19:35:55.563595        3150        629     140.63
# 2    2024-07-27 19:35:55.563595        8786        957     126.21
# 3    2024-06-29 19:35:55.563595        8176        735      16.81
# 4    2024-04-20 19:35:55.563595        2648        158      90.37
# ...                         ...         ...        ...        ...
# 4995 2022-11-23 19:35:55.563595        4005        378      26.48
# 4996 2022-12-04 19:35:55.563595        5007        352     159.27
# 4997 2022-10-10 19:35:55.563595        1280        555      40.35
# 4998 2024-03-23 19:35:55.563595        1763        479      42.48
# 4999 2023-11-23 19:35:55.563595        4138        835      45.05
#
#       QuantitySold  TotalSales    Month Quarter ProductName ProductCategory  \
# 0                4      450.28  2023-10  2023Q4         Red           Books
# ...

# %%
region_sales=merged_data[merged_data['CustomerRegion']=='Dhaka']

# %%
Dha=region_sales.groupby('ProductName')['TotalSales'].sum()

# %%
print('The top products of Dhaka')
print(Dha.sort_values(ascending=False).head(10))
# Out:
# The top products of Dhaka
# ProductName
# Front         9120.78
# Soldier       8491.02
# Determine     6761.20
# Believe       6745.76
# Interest      6169.16
# Understand    6019.40
# Color         5791.52
# Stand         5646.92
# Arrive        5511.75
# Physical      5488.18
# Name: TotalSales, dtype: float64

# %%
Ctg=merged_data[merged_data['CustomerRegion']=='Chittagong']

# %%
Ctg_pro=Ctg.groupby('ProductName')['TotalSales'].sum()

# %%
print('The top products of Chittagong')
print(Ctg_pro.sort_values(ascending=False).head(10))
# Out:
# The top products of Chittagong
# ProductName
# Through      6927.48
# Determine    6752.43
# Notice       6638.97
# Along        6511.12
# Believe      5993.61
# Tree         5722.38
# Hit          5684.58
# Prove        5551.16
# Health       5258.14
# Front        5238.82
# Name: TotalSales, dtype: float64

# %%
merged_data.dtypes
# Out:
# SaleDate           datetime64[ns]
# CustomerID                  int64
# ProductID                   int64
# UnitPrice                 float64
# QuantitySold                int64
# TotalSales                float64
# Month                   period[M]
# Quarter             period[Q-DEC]
# ProductName                object
# ProductCategory            object
# Supplier                   object
# CustomerAge                 int64
# CustomerGender             object
# CustomerRegion             object
# dtype: object

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ##### Monthly Sales Trend

# %%
# Plot the monthly sales trend
# Set up the figure with a larger size for better visibility
plt.figure(figsize=(14, 8))

# Use a clean and modern style
plt.style.use('seaborn-v0_8-darkgrid')

# Plot the monthly sales trend with enhanced markers and line settings
monthly_sales.plot(kind='line', marker='o', markersize=8, color='#1f77b4', linewidth=2.5)

# Add a title with improved font settings
plt.title('Monthly Sales Trend', font='Serif', fontsize=20, fontweight='bold', color='#333333', pad=20)

# Customize the x and y labels with better fonts and padding
plt.xlabel('Month', fontsize=16, labelpad=15, color='#333333')
plt.ylabel('Total Sales (BDT)', fontsize=16, labelpad=15, color='#333333')

# Customize the tick parameters for better readability
plt.xticks(fontsize=14, rotation=45, color='#333333')
plt.yticks(fontsize=14, color='#333333')

# Add gridlines to enhance readability, with subtle styling
plt.grid(True, linestyle='--', linewidth=0.7, alpha=0.7)

# Use tight layout to prevent clipping and improve spacing
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ##### Top-Performing Product Categories

# %%
import matplotlib.pyplot as plt

# Set up the figure with a larger size and higher DPI for better resolution
plt.figure(figsize=(12, 8), dpi=300)

# Use a clean and minimalistic style
plt.style.use('seaborn-v0_8-whitegrid')

# Create the bar plot with customized colors and edges
p_category.plot(kind='bar', color='#2c7f2e', edgecolor='black', linewidth=1.5)

# Add a title with improved font settings
plt.title('Top-Performing Product Categories', font='Serif', fontsize=20, fontweight='bold', color='#333333', pad=20)

# Customize the x and y labels with improved font settings and spacing
plt.xlabel('Product Categories', font='Serif', fontsize=14, labelpad=15, color='#333333')
plt.ylabel('Total Sales (BDT)', font='Serif', fontsize=14, labelpad=15, color='#333333')

# Customize the tick parameters
plt.xticks(fontsize=12, rotation=45, color='#333333')
plt.yticks(fontsize=12, color='#333333')

# Add gridlines only on the y-axis for better readability
plt.grid(True, axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Tighten layout to ensure nothing is cut off and improve spacing
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ##### Customer Segmentation Pie Chart

# %%
# Grouping the data by 'CustomerRegion' and counting the number of unique 'CustomerID'
customer_segments = merged_data.groupby('CustomerRegion')['CustomerID'].nunique()

# Plotting the pie chart
plt.figure(figsize=(10, 7))
plt.pie(customer_segments, labels=customer_segments.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)

# Adding a title to the chart
plt.title('Customer Segmentation by Region', fontsize=16, fontweight='bold')

# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

# Display the plot
plt.show()

# %%
# Plot top-performing regions
plt.figure(figsize=(10, 6),dpi=300)
region.plot(kind='bar', color='orange', edgecolor='black')
plt.title('Top-Performing Regions', fontsize=16, fontweight='bold')
plt.xlabel('Region (City in Bangladesh)', fontsize=14)
plt.ylabel('Total Sales (BDT)', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
